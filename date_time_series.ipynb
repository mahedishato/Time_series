# %%
import pandas as pd 
import numpy as np

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# ####working with date

# %%
date['date']= pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
#extrect year 

date['date_year']= date['date'].dt.year

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-12-10        5628       25       3       2019
# 1 2018-08-15        3646       14     157       2018
# 2 2018-10-23        1859       25       1       2018
# 3 2019-08-17        7292       25       1       2019
# 4 2019-01-06        4344       25       3       2019

# %%
#extrect month 
date['date_month'] = date['date'].dt.month

# %%
date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year  date_month
# 324 2018-12-14        1238       13       7       2018          12
# 497 2018-11-26        4667        9       1       2018          11
# 510 2019-04-04        5953       13      34       2019           4
# 620 2019-03-21        3220       28       1       2019           3
# 515 2019-06-22        4611       26       8       2019           6

# %%
#extrect month name 
date['date_month_name'] = date['date'].dt.month_name()

# %%
date.sample(4)
# Out:
#           date  product_id  city_id  orders  date_year  date_month  \
# 285 2018-10-19        6619        4       1       2018          10
# 841 2019-11-17        5250        3      13       2019          11
# 898 2019-02-20        2945       22       2       2019           2
# 750 2018-09-18        6430       13       2       2018           9
#
#     date_month_name
# 285         October
# 841        November
# 898        February
# 750       September

# %%
#extrect day 
date['date_day'] = date['date'].dt.day

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#   date_month_name  date_day
# 0        December        10
# 1          August        15
# 2         October        23
# 3          August        17
# 4         January         6

# %%
#day of week (week er kon din)

date['date_week_day'] = date['date'].dt.dayofweek

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#   date_month_name  date_day  date_week_day
# 0        December        10              1
# 1          August        15              2
# 2         October        23              1
# 3          August        17              5
# 4         January         6              6

# %%
#day name 
date['date_day_name']= date['date'].dt.day_name()

# %%
date.sample(4)
# Out:
#           date  product_id  city_id  orders  date_year  date_month  \
# 870 2019-08-10        3800       16       2       2019           8
# 156 2019-04-25         568        8      25       2019           4
# 236 2018-08-24        4576       22       3       2018           8
# 869 2018-12-30        2542        0       2       2018          12
#
#     date_month_name  date_day  date_week_day date_day_name
# 870          August        10              5      Saturday
# 156           April        25              3      Thursday
# 236          August        24              4        Friday
# 869        December        30              6        Sunday

# %%
#week of the year 
date['week_of_year'] = date['date'].dt.week
date.sample(4)
# Out:
# C:\Users\mahed\AppData\Local\Temp\ipykernel_1700\2173526127.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   date['week_of_year'] = date['date'].dt.week
#           date  product_id  city_id  orders  date_year  date_month  \
# 924 2018-09-01        1484        3      19       2018           9
# 906 2019-02-18        5428       26       1       2019           2
# 110 2019-08-13        7059       14      11       2019           8
# 734 2018-12-21        1557       30       1       2018          12
#
#     date_month_name  date_day  date_week_day date_day_name  week_of_year
# 924       September         1              5      Saturday            35
# 906        February        18              0        Monday             8
# 110          August        13              1       Tuesday            33
# 734        December        21              4        Friday            51

# %%
#extrect quater 
date['quater']= date['date'].dt.quarter
date.sample(4)
# Out:
#           date  product_id  city_id  orders  date_year  date_month  \
# 408 2019-05-31        1341       13       8       2019           5
# 130 2019-07-12        2242        8       2       2019           7
# 824 2018-09-24        7384        5       9       2018           9
# 447 2019-01-18         621       22      25       2019           1
#
#     date_month_name  date_day  date_week_day date_day_name  week_of_year  \
# 408             May        31              4        Friday            22
# 130            July        12              4        Friday            28
# 824       September        24              0        Monday            39
# 447         January        18              4        Friday             3
#
#      quater
# 408       2
# 130       3
# 824       3
# 447       1

# %% [markdown]
# #working with time

# %%
time.sample(1)
# Out:
#                     date                                                msg
# 472  2012-07-02 01:04:00  ИЩУ СИПМ.ДЕВ.ДО22 ЗВ.ПИШ.0937801619 0937801619...

# %%
time['date']= pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour']= time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['secound']= time['date'].dt.second

# %%
time.sample(5)
# Out:
#                    date                                                msg  \
# 47  2014-05-11 00:31:00  дев. обменяется и* фото с дев. Только ммс. Т. ...
# 761 2012-08-08 02:00:00                                      Дима  + Света
# 107 2012-09-15 00:34:00  приветос Модер.спасибо с третьего раза песню п...
# 160 2014-05-20 00:43:00  Симп Мужчина! Желает завтра встр с дев.жен для...
# 651 2016-01-03 00:44:00  ВЗРОСЛАЯ ДЕВУШКА ПОЗНАКОМИТСЯ С ИНТЕРЕСНЫМ ПАР...
#
#      hour  min  secound
# 47      0   31        0
# 761     2    0        0
# 107     0   34        0
# 160     0   43        0
# 651     0   44        0

# %%
time['times']= time['date'].dt.time
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  secound     times
# 0     0   50        0  00:50:00
# 1    23   40        0  23:40:00
# 2     0   21        0  00:21:00
# 3     0   31        0  00:31:00
# 4    23   11        0  23:11:00
